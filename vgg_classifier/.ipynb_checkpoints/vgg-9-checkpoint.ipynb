# %%
from keras.applications import VGG16
import keras
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, ZeroPadding2D, AveragePooling2D
from keras.layers.normalization import BatchNormalization
from keras.optimizers import Adam

from keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing import image
from keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping

import numpy as np
import os

import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # 1. Define Input Parameters

# %%
# vgg was designed to work on 224X224 input image
img_rows, img_cols = (64, 64)

# define number of classes in data
num_classes = 17

# define batch size
batch_size = 32

# %% [markdown]
# # 2. Load Data

# %%
train_images_dir = '17_flowers/train'
test_images_dir = '17_flowers/validation'

# Define image data generators
# perform image augmentation to save model from overfitting the training data
# augmentation will create various batches of images & will apply various transformations on images like flipping
# hence providing the overall more training data without adding anymore images
# shear_range & zoom_range are to define how much randomization we want to apply on data
train_datagen = ImageDataGenerator(rescale=1./255,
                                   rotation_range=45,
                                   width_shift_range=0.3,
                                   height_shift_range=0.3,
                                   horizontal_flip=True,
                                   fill_mode='nearest')

test_datagen = ImageDataGenerator(rescale=1./255)

# target size: same as input shape in classifier as this will be the input to classifier
# batch_size: number of inputs after which weights will be updated
# class_mode: ['binary', 'categorical']
training_set = train_datagen.flow_from_directory(train_images_dir,
                                                target_size = (img_rows, img_cols),
                                                batch_size = batch_size,
                                                class_mode = 'categorical',
                                                seed=67)

test_set = test_datagen.flow_from_directory(test_images_dir,
                                            target_size = (img_rows, img_cols),
                                            batch_size = batch_size,
                                            class_mode = 'categorical')
# Out:
# Found 1190 images belonging to 17 classes.
# Found 170 images belonging to 17 classes.

# %% [markdown]
# # 3. Setup the Model

# %%
# 1. load the mobileNet model without the top layer so that we can add custom layers in the end as per our data
vgg16 = VGG16(weights='imagenet',
                  include_top=False,
                  input_shape = (img_rows, img_cols, 3))
vgg16.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 64, 64, 3)         0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 64, 64, 64)        1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 64, 64, 64)        36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 32, 32, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 32, 32, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 32, 32, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 16, 16, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 16, 16, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 8, 8, 256)         0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 8, 8, 512)         1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 2, 2, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 2. freeze the layers of model
for layer in vgg16.layers:
    layer.trainable = False
    
# print the layer names
for i, layer in enumerate(vgg16.layers):
    print(str(i)+" "+layer.__class__.__name__, layer.trainable)
# Out:
# 0 InputLayer False
# 1 Conv2D False
# 2 Conv2D False
# 3 MaxPooling2D False
# 4 Conv2D False
# 5 Conv2D False
# 6 MaxPooling2D False
# 7 Conv2D False
# 8 Conv2D False
# 9 Conv2D False
# 10 MaxPooling2D False
# 11 Conv2D False
# 12 Conv2D False
# 13 Conv2D False
# 14 MaxPooling2D False
# 15 Conv2D False
# 16 Conv2D False
# 17 Conv2D False
# 18 MaxPooling2D False

# %%
# 3. Add custom layers as per data
# remove the layers above 9th to make vgg9 model
x = vgg16.layers[8].output

# Max Pooling with Dropout
pool1 = MaxPooling2D(pool_size=(2, 2))(x)
drop1 = Dropout(0.2)(pool1)

# First set of FC or Dense Layers
flat1 = Flatten()(drop1)
dense1 = Dense(1024, activation='relu')(flat1)
bn1 = BatchNormalization()(dense1)
drop2 = Dropout(0.5)(bn1)

# Second set of FC or Dense Layers
dense2 = Dense(1024, activation='relu')(drop2)
bn2 = BatchNormalization()(dense2)
drop3 = Dropout(0.5)(bn2)

# Final Dense Layer
dense3 = Dense(num_classes, activation='softmax')(drop3)

model = Model(inputs=vgg16.inputs, output=dense3)
model.compile(optimizer = Adam(lr=0.001), loss = 'categorical_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 64, 64, 3)         0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 64, 64, 64)        1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 64, 64, 64)        36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 32, 32, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 32, 32, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 32, 32, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 16, 16, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 16, 16, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 256)         0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 8, 8, 256)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 16384)             0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1024)              16778240
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 1024)              4096
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 1024)              4096
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 17)                17425
# =================================================================
# Total params: 18,998,865
# Trainable params: 17,849,361
# Non-trainable params: 1,149,504
# _________________________________________________________________
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:23: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=[<tf.Tenso..., outputs=Tensor("de...)`

# %% [markdown]
# # 4. Define other model parameters

# %%
checkpoint = ModelCheckpoint('flower17.h5',
                             monitor='val_loss',
                             mode='min',
                             save_best_only=True,
                             verbose=1
                            )

earlystop = EarlyStopping(monitor='val_loss',
                          min_delta=0,
                          patience=5,
                          verbose=1,
                          restore_best_weights=True)

reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              factor = 0.2,
                              min_delta=0.0001,
                              patience=3,
                              verbose=1)

# %% [markdown]
# # 5. Fitting the model

# %%
history = model.fit_generator(training_set,
                              steps_per_epoch = 1190//batch_size,
                              epochs = 25,
                              validation_data = test_set,
                              validation_steps = 170//batch_size,
                              callbacks=[checkpoint, earlystop, reduce_lr])
# Out:
# Epoch 1/25
# 37/37 [==============================] - 12s 330ms/step - loss: 3.5436 - acc: 0.1900 - val_loss: 8.0673 - val_acc: 0.1313
#
# Epoch 00001: val_loss improved from inf to 8.06727, saving model to flower17.h5
# Epoch 2/25
# 37/37 [==============================] - 10s 262ms/step - loss: 2.7881 - acc: 0.2958 - val_loss: 3.4683 - val_acc: 0.3623
#
# Epoch 00002: val_loss improved from 8.06727 to 3.46834, saving model to flower17.h5
# Epoch 3/25
# 37/37 [==============================] - 10s 263ms/step - loss: 2.4477 - acc: 0.3492 - val_loss: 1.9946 - val_acc: 0.4928
#
# Epoch 00003: val_loss improved from 3.46834 to 1.99462, saving model to flower17.h5
# Epoch 4/25
# 37/37 [==============================] - 10s 266ms/step - loss: 2.1614 - acc: 0.3915 - val_loss: 2.6216 - val_acc: 0.5000
#
# Epoch 00004: val_loss did not improve from 1.99462
# Epoch 5/25
# 37/37 [==============================] - 10s 279ms/step - loss: 1.9587 - acc: 0.4664 - val_loss: 1.5841 - val_acc: 0.5797
#
# Epoch 00005: val_loss improved from 1.99462 to 1.58408, saving model to flower17.h5
# Epoch 6/25
# 37/37 [==============================] - 10s 269ms/step - loss: 1.8602 - acc: 0.4780 - val_loss: 1.3273 - val_acc: 0.6377
#
# Epoch 00006: val_loss improved from 1.58408 to 1.32730, saving model to flower17.h5
# Epoch 7/25
# 37/37 [==============================] - 10s 272ms/step - loss: 1.8993 - acc: 0.4684 - val_loss: 1.1284 - val_acc: 0.6937
#
# Epoch 00007: val_loss improved from 1.32730 to 1.12838, saving model to flower17.h5
# Epoch 8/25
# 37/37 [==============================] - 10s 272ms/step - loss: 1.7087 - acc: 0.4935 - val_loss: 1.1265 - val_acc: 0.6377
#
# Epoch 00008: val_loss improved from 1.12838 to 1.12652, saving model to flower17.h5
# Epoch 9/25
# 37/37 [==============================] - 10s 269ms/step - loss: 1.7138 - acc: 0.5129 - val_loss: 1.2386 - val_acc: 0.6449
#
# Epoch 00009: val_loss did not improve from 1.12652
# Epoch 10/25
# 37/37 [==============================] - 10s 278ms/step - loss: 1.7513 - acc: 0.5121 - val_loss: 1.2330 - val_acc: 0.6667
#
# Epoch 00010: val_loss did not improve from 1.12652
# Epoch 11/25
# 37/37 [==============================] - 10s 266ms/step - loss: 1.6526 - acc: 0.5174 - val_loss: 1.2003 - val_acc: 0.6594
#
# Epoch 00011: val_loss did not improve from 1.12652
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 12/25
# 37/37 [==============================] - 10s 260ms/step - loss: 1.5357 - acc: 0.5283 - val_loss: 0.7813 - val_acc: 0.7681
#
# Epoch 00012: val_loss improved from 1.12652 to 0.78129, saving model to flower17.h5
# Epoch 13/25
# 37/37 [==============================] - 10s 283ms/step - loss: 1.4119 - acc: 0.5767 - val_loss: 0.7353 - val_acc: 0.7688
#
# Epoch 00013: val_loss improved from 0.78129 to 0.73528, saving model to flower17.h5
# Epoch 14/25
# 37/37 [==============================] - 13s 358ms/step - loss: 1.5212 - acc: 0.5419 - val_loss: 0.6294 - val_acc: 0.7899
#
# Epoch 00014: val_loss improved from 0.73528 to 0.62936, saving model to flower17.h5
# Epoch 15/25
# 37/37 [==============================] - 10s 268ms/step - loss: 1.4289 - acc: 0.5531 - val_loss: 0.7220 - val_acc: 0.7536
#
# Epoch 00015: val_loss did not improve from 0.62936
# Epoch 16/25
# 37/37 [==============================] - 10s 274ms/step - loss: 1.2836 - acc: 0.6071 - val_loss: 0.7969 - val_acc: 0.7246
#
# Epoch 00016: val_loss did not improve from 0.62936
# Epoch 17/25
# 37/37 [==============================] - 10s 266ms/step - loss: 1.4698 - acc: 0.5628 - val_loss: 0.7785 - val_acc: 0.7681
#
# Epoch 00017: val_loss did not improve from 0.62936
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 18/25
# 37/37 [==============================] - 11s 287ms/step - loss: 1.3137 - acc: 0.5906 - val_loss: 0.7501 - val_acc: 0.7681
#
# Epoch 00018: val_loss did not improve from 0.62936
# Epoch 19/25
# 37/37 [==============================] - 10s 267ms/step - loss: 1.3097 - acc: 0.5843 - val_loss: 0.7327 - val_acc: 0.7688
#
# Epoch 00019: val_loss did not improve from 0.62936
# Restoring model weights from the end of the best epoch
# Epoch 00019: early stopping

# %% [markdown]
# # 6. Predictions

# %%
# get all classes folder names
image_folders = os.listdir(test_images_dir)
for i in range(17):
    # choose one random folder (0, 16)
    folder_index = i

    # get all images in the specified folder
    val_images = os.listdir(os.path.join(test_images_dir, image_folders[folder_index]))
    index = 5

    # load image
    test_image = image.load_img(os.path.join(test_images_dir, image_folders[folder_index]+'/'+val_images[index]), target_size=(img_cols, img_rows))
    plt.imshow(test_image, interpolation='bilinear')
    # convert into array
    # dimension = 64, 64, 3
    test_image = image.img_to_array(test_image)
    # add batch size as 4th dimension
    test_image = np.expand_dims(test_image, axis = 0)
    # predict on rescaled image
    result = model.predict(test_image/255)

    # get class indices
    class_labels = {v:k for k,v in training_set.class_indices.items()}

    # get class attributes
    print('Predicted Class:', class_labels[np.argmax(result)])
    print('Actual Class:', image_folders[folder_index])
    plt.show()
# Out:
# Predicted Class: bluebell
# Actual Class: bluebell
# Predicted Class: colts_foot
# Actual Class: colts_foot
# Predicted Class: buttercup
# Actual Class: buttercup
# Predicted Class: daisy
# Actual Class: daisy
# Predicted Class: snowdrop
# Actual Class: snowdrop
# Predicted Class: pansy
# Actual Class: crocus
# Predicted Class: cowslip
# Actual Class: cowslip
# Predicted Class: dandelion
# Actual Class: dandelion
# Predicted Class: lily_valley
# Actual Class: lily_valley
# Predicted Class: iris
# Actual Class: iris
# Predicted Class: fritillary
# Actual Class: fritillary
# Predicted Class: daffodil
# Actual Class: daffodil
# Predicted Class: pansy
# Actual Class: pansy
# Predicted Class: windflower
# Actual Class: windflower
# Predicted Class: tigerlily
# Actual Class: tigerlily
# Predicted Class: cowslip
# Actual Class: tulip
# Predicted Class: sunflower
# Actual Class: sunflower
